# %%
import pandas as pd

catchment_info = pd.read_csv('/home/mettalbi/projects/smash-maintenance-1.0.x/tests/results/catchment_infos.csv')
catchment_info
# Out:
#              id    area  mean_annual_rainfall  mean_annual_pet  \
# 0    K003002010   227.0           1198.556144       514.926973
# 1    K201082001    48.8           1205.560710       539.132161
# 2    O163401001   196.0            631.760707       799.850730
# 3    O331401002    42.9           1552.753335       571.759956
# 4    V352401001   380.0            733.664227       653.976768
# ..          ...     ...                   ...              ...
# 121  Y561503001   279.0            994.775855       718.899532
# 122  Y604201001   676.0            904.312964       509.379458
# 123  Y612501201  1064.0            881.537992       543.018058
# 124  Y642401001   262.0            952.256322       630.198831
# 125  Y643401001   451.0            968.393217       663.897632
#
#      mean_hourly_discharge     slope  drainage_density  karst_zone  \
# 0                 1.504665  0.991743         16.906130    0.000000
# 1                 1.426142  1.173790         18.686491    0.000000
# ...

# %%
catchment_info.describe()
# Out:
#               area  mean_annual_rainfall  mean_annual_pet  \
# count   126.000000            126.000000       126.000000
# mean    402.985716            896.333125       726.479102
# std     415.253789            248.738398        87.816090
# min      28.000000            510.936973       490.319245
# 25%     131.500000            717.317647       662.282730
# 50%     239.000000            821.822533       741.459218
# 75%     559.000000           1017.763538       793.139408
# max    1958.000000           1552.753335       883.080078
#
#        mean_hourly_discharge       slope  drainage_density  karst_zone  \
# count             126.000000  126.000000        126.000000  126.000000
# mean                5.392676    2.091782         17.782119    0.416686
# std                 7.228438    1.321106          3.504252    0.342659
# min                 0.066604    0.007540          9.820255    0.000000
# 25%                 0.876861    1.134716         15.795741    0.086646
# ...

# %%
catchment_info['slope'].value_counts()
# Out:
# slope
# 2.413292    2
# 0.886989    2
# 1.134716    2
# 2.117569    1
# 2.152038    1
#            ..
# 4.169264    1
# 3.669932    1
# 2.077148    1
# 2.123094    1
# 4.207306    1
# Name: count, Length: 123, dtype: int64
